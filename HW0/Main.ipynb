# %% [markdown]
# Меринов Артем Александрович
#
# artemmerinov@yandex.ru

# %% [markdown]
# # Artificial Neural Networks

# %% [markdown]
# The goal of this homework is simple, yet an actual implementation may take some time :). We are going to write an Artificial Neural Network (almost) from scratch, then use it to recognize digits on the MNIST dataset

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

from time import time, sleep
from datetime import datetime
from IPython import display

# %matplotlib inline

# %% [markdown]
# # Framework

# %% [markdown]
# Implement everything in `Modules.ipynb`. Read all the comments thoughtfully to ease the pain. Please try not to change the prototypes.
#
# Do not forget, that each module should return AND store `output` and `gradInput`.
#
# The typical assumption is that `module.backward` is always executed after `module.forward`,
# so `output` is stored, this would be useful for `SoftMax`.

# %%
# load your modules
# %run Modules.ipynb

# %% [markdown]
# Optimizer is implemented for you.

# %%
def sgd_momentum(x, dx, config, state):
    """
        This is a very ugly implementation of sgd (Stochastic gradient descent) with momentum 
        just to show an example how to store old grad in state.
        
        config:
            - momentum
            - learning_rate
        state:
            - old_grad
    """
    
    # x and dx have complex structure, old dx will be stored in a simpler one
    state.setdefault('old_grad', {})
    
    i = 0 
    for cur_layer_x, cur_layer_dx in zip(x,dx): 
        for cur_x, cur_dx in zip(cur_layer_x,cur_layer_dx):
            
            cur_old_grad = state['old_grad'].setdefault(i, np.zeros_like(cur_dx))
            
            np.add(config['momentum'] * cur_old_grad, config['learning_rate'] * cur_dx, out = cur_old_grad)
            
            cur_x -= cur_old_grad
            i += 1
        
# batch generator
def get_batches( (X, Y) , batch_size):
    n_samples = X.shape[0]
        
    # Shuffle at the start of epoch
    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        
        batch_idx = indices[start:end]
    
        yield X[batch_idx], Y[batch_idx]

# helper train function
def do_train(XX, YY, net, net_criterion):
    st = datetime.now()
    loss_history = []

    for i in range(n_epoch):
        for x_batch, y_batch in get_batches( (XX, YY) , batch_size):

            net.zeroGradParameters()

            # Forward
            predictions = net.forward(x_batch)
            loss = net_criterion.forward(predictions, y_batch)

            # Backward
            dp = net_criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)

            # Update weights
            sgd_momentum(net.getParameters(), 
                         net.getGradParameters(), 
                         optimizer_config,
                         optimizer_state)      

            loss_history.append(loss)

        # Visualize
        display.clear_output(wait=True)
        plt.figure(figsize=(14, 10))

        plt.title("Training loss, epoch {}/{}".format(str(i+1), str(n_epoch)))
        plt.xlabel("#iteration")
        plt.ylabel("loss")
        plt.plot(loss_history, 'b')
        plt.show()

        print('Current loss: %f' % loss)
        
    print str(n_epoch), 'epochs trained for', datetime.now() - st
        
    return loss_history

# %% [markdown]
# # Toy example

# %% [markdown]
# Use this example to debug your code, start with logistic regression and then test other layers. You do not need to change anything here. This code is provided for you to test the layers. Also it is easy to use this code in MNIST task.

# %%
# Generate some data
N = 500

X1 = np.random.randn(N,2) + np.array([2,2])
X2 = np.random.randn(N,2) + np.array([-2,-2])

Ytoy = np.concatenate([np.ones(N),np.zeros(N)])[:,None]
Ytoy = np.hstack([Ytoy, 1-Ytoy])

Xtoy = np.vstack([X1,X2])
plt.scatter(Xtoy[:,0],Xtoy[:,1], c = Ytoy[:,0], edgecolors= 'none')

# %% [markdown]
# ### Once you are done with Linear and Softmax modules, try to run this **logistic regression**  architecture

# %%
# define architecture
criterion = ClassNLLCriterion()
LRnet = Sequential()
LRnet.add(Linear(2, 4))
LRnet.add(ReLU())
LRnet.add(Linear(4, 2))
LRnet.add(SoftMax())
print LRnet

# define optimization parameters
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128
# Out:
# Linear 2 -> 4
# ReLU
# Linear 4 -> 2
# SoftMax

# %% [markdown]
# ### Correct output will be visible until you run the cell

# %%
_ = do_train(Xtoy, Ytoy, LRnet, criterion)
# Out:
# Current loss: 0.004729
# 20 epochs trained for 0:00:04.298811

# %%
# Use this function to measure the accuracy of your models
def evaluate(network, test_data, test_labels):
    """
    Uses one-hot encoded labeled data to evaluate a given model
    """
    
    predictions = network.forward(test_data)
    correct = sum(np.argmax(predictions, axis=1) == np.argmax(test_labels, axis=1))
    cor_frac = correct/float(test_data.shape[0])
    print("Model accuracy = {} %".format(cor_frac*100))
    return cor_frac

# %%
acc = evaluate(LRnet, Xtoy, Ytoy)
# Out:
# Model accuracy = 99.8 %

# %% [markdown]
# # Digit classification

# %% [markdown]
# We are using [MNIST](http://yann.lecun.com/exdb/mnist/) as our dataset. Lets start with [cool visualization](http://scs.ryerson.ca/~aharley/vis/).

# %% [markdown]
# ### **Download** the MNIST dataset

# %%
import os
from sklearn.datasets import fetch_mldata

# Fetch MNIST dataset and create a local copy.
# This might take a minute or two...

if os.path.exists('mnist.npz'):
    with np.load('mnist.npz', 'r') as data:
        X = data['X']
        y = data['y']
else:
    mnist = fetch_mldata("mnist-original")
    X, y = mnist.data / 255.0, mnist.target
    np.savez('mnist.npz', X=X, y=y)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
print X_train.shape, y_train.shape # Should be like this
# Out:
# (56000, 784) (56000,)

# %% [markdown]
# ### One-hot encode the labels first.

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(sparse=False)
enc.fit(y_train.reshape((-1, 1)))
y_train = enc.transform(y_train.reshape((-1, 1)), )

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=.1)

# %%
print X_train.shape, y_train.shape
# Out:
# (50400, 784) (50400, 10)

# %% [markdown]
# ## Science time!

# %% [markdown]
# - Compare **`ReLU`, `ELU`** and **`LeakyReLU`** activation functions.
# You would better pick the best optimizer params for each of them, but it is overkill for now. Use an architecture of your choice for the comparison.
# - Plot the losses from all tested architectures on one plot. You may use the provided code.
# - Hint: logloss for MNIST should be well below 0.5.

# %% [markdown]
# ## net_ReLU

# %%
# define architecture with ReLU activation
criterion = ClassNLLCriterion() # You gonna need multiclass criterion for this one
net_ReLU = Sequential()
net_ReLU.add(Linear(X.shape[1], 100))
net_ReLU.add(ReLU())
net_ReLU.add(Linear(100, 10))
net_ReLU.add(SoftMax())
print net_ReLU

# define optimization parameters
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

net_ReLU_loss = do_train(X_train, y_train, net_ReLU, criterion)
# Out:
# Current loss: 0.001707
# 20 epochs trained for 0:00:31.511905

# %%
acc_ReLU = evaluate(net_ReLU, X_validation, y_validation)
# Out:
# Model accuracy = 98.0 %

# %% [markdown]
# # net_ReLU + BatchMeanSubtraction

# %%
# define architecture with ReLU activation
criterion = ClassNLLCriterion() # You gonna need multiclass criterion for this one
net_ReLUB = Sequential()
net_ReLUB.add(Linear(X.shape[1], 100))
net_ReLUB.add(BatchMeanSubtraction(.8))
net_ReLUB.add(ReLU())
net_ReLUB.add(Linear(100, 10))
net_ReLUB.add(SoftMax())
print net_ReLUB

# define optimization parameters
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

net_ReLUB_loss = do_train(X_train, y_train, net_ReLUB, criterion)
# Out:
# Current loss: 0.000326
# 20 epochs trained for 0:00:29.439586

# %%
acc_ReLUB = evaluate(net_ReLUB, X_validation, y_validation)
# Out:
# Model accuracy = 97.8035714286 %

# %% [markdown]
# # net_LeakyReLU

# %%
# define architecture with LeakyReLU activation
criterion = ClassNLLCriterion()
net_LeakyReLU = Sequential()
net_LeakyReLU.add(Linear(X.shape[1], 100))
net_LeakyReLU.add(ReLU())
net_LeakyReLU.add(Linear(100, 10))
net_LeakyReLU.add(SoftMax())
print net_LeakyReLU

# define optimization parameters
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

net_LeakyReLU_loss = do_train(X_train, y_train, net_LeakyReLU, criterion)
# Out:
# Current loss: 0.002245
# 20 epochs trained for 0:00:34.521029

# %%
acc_LeakyReLU = evaluate(net_LeakyReLU, X_validation, y_validation)
# Out:
# Model accuracy = 97.7857142857 %

# %% [markdown]
# # net_ELU

# %%
# define architecture with ELU activation
criterion = ClassNLLCriterion()
net_ELU = Sequential()
net_ELU.add(Linear(X.shape[1], 100))
net_ELU.add(ELU())
net_ELU.add(Linear(100, 10))
net_ELU.add(SoftMax())
print net_ELU

# define optimization parameters
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

net_ELU_loss = do_train(X_train, y_train, net_ELU, criterion)
# Out:
# Current loss: 0.001047
# 20 epochs trained for 0:00:36.132783

# %%
acc_ELU = evaluate(net_ELU, X_validation, y_validation)
# Out:
# Model accuracy = 98.0 %

# %%
print acc_ReLU, acc_ReLUB, acc_LeakyReLU, acc_ELU
# Out:
# 0.978571428571 0.978035714286 0.977857142857 0.98

# %% [markdown]
# ### Plot all losses on  a single graph

# %%
# plot all losses on  a single graph
names = ['ReLU','ELU', 'LeakyReLU']
rezs = [net_ReLU_loss, net_ELU_loss, net_LeakyReLU_loss]

plt.figure(figsize=(14, 10))
for i, n in enumerate(names):
    plt.plot(range(len(rezs[i])),rezs[i], label=n)
    
plt.legend(loc='best',prop={'size':16})
plt.xlabel('log_iterations')
plt.ylabel('loss')
plt.title('Comparison of activation functions')
plt.xscale('log')

plt.show()

# %% [markdown]
# Write your personal opinion on the activation functions, think about computation times too.

# %% [markdown]
# Finally, use all the knowledge you've gained to build a ***super-cool*** model to reach maximum accuracy of MNIST dataset. See if you can get below 2% error. You may want to use modules from the bonus section. Good luck!

# %%
criterion = ClassNLLCriterion()
nets = []

n_epoch = 20

net = Sequential()
net.add(Linear(X.shape[1], 512))
net.add(Dropout(.5))
net.add(BatchMeanSubtraction(.85))
net.add(ReLU())
net.add(Linear(512, 256))
net.add(Dropout(.4))
net.add(BatchMeanSubtraction(.85))
net.add(Linear(256, 10))
net.add(SoftMax())

optimizer_state = {}
net_loss = do_train(X_train, y_train, net, criterion)
# Out:
# Current loss: 0.034569
# 20 epochs trained for 0:02:13.709551

# %%
acc = evaluate(net, X_validation, y_validation)
# Out:
# Model accuracy = 96.2321428571 %
